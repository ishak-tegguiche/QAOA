# %% [markdown]
# ### Impact of Circuit Depth on the Performance of QAOA
# The first objective of this work is to systematically evaluate the influence of circuit depth in the QAOA. In particular, we investigate how increasing the number of QAOA layers ($p=1,2,3,4$) affects both the quality of the obtained solutions and the computational cost of the algorithm.
#
# To conduct this study, we consider the Max-Cut Problem. The algorithm is applied to graphs of different sizes containing 8, 10, and 12 nodes, allowing us to analyze how circuit depth impacts performance as the problem size increases.

# %% [markdown]
# ### Import Libraries

# %%
import pennylane as qml 
from pennylane import numpy as np 
import time 
import matplotlib.pyplot as plt 
import networkx as nx 

np.random.seed(42)
# Out:
# C:\Users\Probook\anaconda3\Lib\site-packages\pennylane\__init__.py:212: PennyLaneDeprecationWarning: PennyLane v0.44 has dropped maintainence support for NumPy < 2.0.0. You have version 1.26.4 installed. Future versions of PennyLane will not work with NumPy<2.0. Please consider upgrading NumPy using `python -m pip install numpy --upgrade`.
#   warnings.warn(

# %% [markdown]
# ### Define 3 Graphs: 8, 10, 12 nodes

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Generate graphs
graphs = {
    8: [
        (0,1), (0,2), (0,3),
        (1,4), (1,5),
        (2,4), (2,6),
        (3,5), (3,7),
        (4,7),
        (5,6),
        (6,7)
    ],
    10: [
        (0,1), (0,2), (0,3),
        (1,4), (1,5),
        (2,4), (2,6),
        (3,5), (3,7),
        (4,8),
        (5,9),
        (6,7), (6,9),
        (7,8),
        (8,9)
    ],
    12: [
        (0,1), (0,2), (0,3),
        (1,4), (1,5),
        (2,4), (2,6),
        (3,5), (3,7),
        (4,8),
        (5,9),
        (6,7), (6,10),
        (7,11),
        (8,9), (8,10),
        (9,11),
        (10,11)
    ]

}

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

for idx, n_wires in enumerate([8, 10, 12]):
    ax = axes[idx]
    
    # Create NetworkX graph
    G = nx.Graph()
    G.add_edges_from(graphs[n_wires])
    
    # Layout
    pos = nx.spring_layout(G, seed=42, k=1.5)
    
    # Draw
    nx.draw_networkx_nodes(G, pos, node_color='lightblue', 
                           node_size=500, edgecolors='black', 
                           linewidths=2, ax=ax)
    nx.draw_networkx_labels(G, pos, font_size=10, 
                            font_weight='bold', ax=ax)
    nx.draw_networkx_edges(G, pos, edge_color='gray', 
                           width=2, ax=ax)
    
    ax.set_title(f'{n_wires}-Node Graph ({len(graphs[n_wires])} edges)', 
                 fontsize=13, fontweight='bold')
    ax.axis('off')

plt.tight_layout()
plt.show()

print()

# %% [markdown]
# ### Calculate optimal solution using Brute Force
# Before evaluating the performance of the QAOA, I first compute the exact optimal solution for each graph used in my experiments. To do this, I implement a brute-force search for the Max-Cut Problem.
# I generate all possible partitions of the graph nodes, which correspond to the $2^n$ possible bitstrings for a graph with $n$ nodes. For each partition, I calculate the number of edges that connect nodes belonging to different subsets, which represents the cut value. The partition that produces the highest number of such edges is considered the optimal Max-Cut.
# This step allows me to obtain the optimal cut value for each graph, which I later use as a reference to evaluate how close the QAOA solutions are to the optimal result.

# %%
def compute_optimal_cut(n_wires, graph):
    """Brute force search for optimal MaxCut"""
    best_cut = 0
    
    for partition in range(2**n_wires):
        # Convert partition number to bitstring
        bitstring = format(partition, f'0{n_wires}b')
        
        # Count cut edges
        cut = 0
        for edge in graph:
            if bitstring[edge[0]] != bitstring[edge[1]]:
                cut += 1
        
        if cut > best_cut:
            best_cut = cut
    
    return best_cut

# Calculate optimal cuts for all graphs
optimal_cuts = {}
print("Calculating optimal cuts")
for n_wires, graph in graphs.items():
    optimal_cuts[n_wires] = compute_optimal_cut(n_wires, graph)
    print(f"  {n_wires}-node graph: Optimal cut = {optimal_cuts[n_wires]}")

print()
# Out:
# Calculating optimal cuts
#   8-node graph: Optimal cut = 10
#   10-node graph: Optimal cut = 13
#   12-node graph: Optimal cut = 16

# %% [markdown]
# ### QAOA Functions

# %%
def U_M(beta, n_wires):
    for wire in range(n_wires):
        qml.RX(2 * beta, wires=wire)

def U_C(gamma, graph):
    for edge in graph:
        qml.CNOT(wires=edge)
        qml.RZ(gamma, wires=edge[1])
        qml.CNOT(wires=edge)

def bitstring_to_int(bit_string_sample):
    return int(2 ** np.arange(len(bit_string_sample)) @ bit_string_sample[::-1])

# %% [markdown]
# ### Main Expirement Loop

# %%
results = {}

# Loop over 3 graphs
for n_wires in [8, 10, 12]:
    graph = graphs[n_wires]
    optimal_cut = optimal_cuts[n_wires]
    
    results[n_wires] = {}
    
    # Create device for this graph size
    dev = qml.device("default.qubit", wires=n_wires)
    
    # Define circuit for this graph
    @qml.qnode(dev)
    def circuit(gammas, betas, return_samples=False):
        for wire in range(n_wires):
            qml.Hadamard(wires=wire)
        
        for gamma, beta in zip(gammas, betas):
            U_C(gamma, graph)
            U_M(beta, n_wires)
        
        if return_samples:
            return qml.sample()
        
        C = qml.sum(*(qml.Z(w1) @ qml.Z(w2) for w1, w2 in graph))
        return qml.expval(C)
    
    def objective(params):
        return -0.5 * (len(graph) - circuit(*params))
    
    # Loop over 4 depths: p=1,2,3,4
    for n_layers in [1, 2, 3, 4]:
        print(f"\n{'='*60}")
        print(f"Graph: {n_wires} nodes | Depth: p={n_layers}")
        print(f"{'='*60}")
        
        # Initialize parameters
        init_params = np.ones((2, n_layers), requires_grad=True)
        
        # Initialize optimizer
        opt = qml.AdagradOptimizer(stepsize=0.5)
        
        # Start timing
        start_time = time.time()
        
        # Optimize
        params = init_params.copy()
        steps = 200
        
        for i in range(steps):
            params = opt.step(objective, params)
            
            if (i + 1) % 10 == 0:
                print(f"Step {i+1:3d}: Objective = {-objective(params):.4f}")
        
        # End timing
        elapsed_time = time.time() - start_time
        
        # Get final cut value
        final_cut = -objective(params)
        
        # Calculate approximation ratio
        approx_ratio = final_cut / optimal_cut
        
        # Get circuit depth (estimate)
        circuit_depth = n_layers * (3 * len(graph) + n_wires)
        
        # Sample bitstrings with optimized parameters
        bitstrings = qml.set_shots(circuit, shots=100)(*params, return_samples=True)
        sampled_ints = [bitstring_to_int(string) for string in bitstrings]
        
        # Find most frequent bitstring
        counts = np.bincount(np.array(sampled_ints))
        most_freq_bit_string = np.argmax(counts)
        
        # Store results
        results[n_wires][n_layers] = {
            'approx_ratio': approx_ratio,
            'iterations': steps,
            'time': elapsed_time,
            'circuit_depth': circuit_depth,
            'final_cut': final_cut,
            'optimal_cut': optimal_cut,
            'params': params,
            'bitstrings': sampled_ints,
            'most_frequent': most_freq_bit_string
        }
        
        # Print summary
        print(f"\nResults:")
        print(f"  Final cut: {final_cut:.2f}")
        print(f"  Optimal cut: {optimal_cut}")
        print(f"  Approximation ratio: {approx_ratio:.4f} ({approx_ratio*100:.1f}%)")
        print(f"  Time: {elapsed_time:.2f}s")
        print(f"  Circuit depth: {circuit_depth}")
        print(f"  Most frequent bitstring: {most_freq_bit_string:0{n_wires}b}")

# RESULTS SUMMARY TABLE

print("\n" + "="*80)
print("SUMMARY TABLE - OBJECTIVE 1")
print("="*80)

for n_wires in [8, 10, 12]:
    print(f"\n{n_wires}-node graph (Optimal cut = {optimal_cuts[n_wires]}):")
    print("-"*80)
    print(f"{'p':<5} {'Approx Ratio':<15} {'Time (s)':<12} {'Iterations':<12} {'Circuit Depth':<15}")
    print("-"*80)
    
    for n_layers in [1, 2, 3, 4]:
        r = results[n_wires][n_layers]
        print(f"{n_layers:<5} {r['approx_ratio']:<15.4f} {r['time']:<12.2f} "
              f"{r['iterations']:<12} {r['circuit_depth']:<15}")

print("\n" + "="*80)
# Out:
# ============================================================
# Graph: 8 nodes | Depth: p=1
# ============================================================
# Step  10: Objective = 8.2835
# Step  20: Objective = 8.3093
# Step  30: Objective = 8.3094
# Step  40: Objective = 8.3094
# Step  50: Objective = 8.3094
# Step  60: Objective = 8.3094
# Step  70: Objective = 8.3094
# Step  80: Objective = 8.3094
# Step  90: Objective = 8.3094
# Step 100: Objective = 8.3094
# Step 110: Objective = 8.3094
# Step 120: Objective = 8.3094
# Step 130: Objective = 8.3094
# Step 140: Objective = 8.3094
# Step 150: Objective = 8.3094
# Step 160: Objective = 8.3094
# Step 170: Objective = 8.3094
# Step 180: Objective = 8.3094
# Step 190: Objective = 8.3094
# Step 200: Objective = 8.3094
#
# Results:
#   Final cut: 8.31
#   Optimal cut: 10
#   Approximation ratio: 0.8309 (83.1%)
#   Time: 29.96s
#   Circuit depth: 44
#   Most frequent bitstring: 10001110
#
# ============================================================
# Graph: 8 nodes | Depth: p=2
# ============================================================
# Step  10: Objective = 9.0187
# Step  20: Objective = 9.2378
# Step  30: Objective = 9.2476
# Step  40: Objective = 9.2480
# Step  50: Objective = 9.2480
# Step  60: Objective = 9.2480
# Step  70: Objective = 9.2480
# Step  80: Objective = 9.2480
# Step  90: Objective = 9.2480
# Step 100: Objective = 9.2480
# Step 110: Objective = 9.2480
# Step 120: Objective = 9.2480
# Step 130: Objective = 9.2480
# Step 140: Objective = 9.2480
# Step 150: Objective = 9.2480
# Step 160: Objective = 9.2480
# Step 170: Objective = 9.2480
# Step 180: Objective = 9.2480
# Step 190: Objective = 9.2480
# Step 200: Objective = 9.2480
#
# Results:
#   Final cut: 9.25
#   Optimal cut: 10
#   Approximation ratio: 0.9248 (92.5%)
#   Time: 48.36s
#   Circuit depth: 88
#   Most frequent bitstring: 01110010
#
# ============================================================
# Graph: 8 nodes | Depth: p=3
# ============================================================
# Step  10: Objective = 9.0975
# Step  20: Objective = 9.5597
# Step  30: Objective = 9.6157
# Step  40: Objective = 9.6084
# Step  50: Objective = 9.6508
# Step  60: Objective = 9.6570
# Step  70: Objective = 9.6580
# Step  80: Objective = 9.6582
# Step  90: Objective = 9.6582
# Step 100: Objective = 9.6582
# Step 110: Objective = 9.6582
# Step 120: Objective = 9.6582
# Step 130: Objective = 9.6582
# Step 140: Objective = 9.6582
# Step 150: Objective = 9.6582
# Step 160: Objective = 9.6582
# Step 170: Objective = 9.6582
# Step 180: Objective = 9.6582
# Step 190: Objective = 9.6582
# Step 200: Objective = 9.6582
#
# Results:
#   Final cut: 9.66
#   Optimal cut: 10
#   Approximation ratio: 0.9658 (96.6%)
#   Time: 66.52s
#   Circuit depth: 132
#   Most frequent bitstring: 01110010
#
# ============================================================
# Graph: 8 nodes | Depth: p=4
# ============================================================
# Step  10: Objective = 6.9189
# Step  20: Objective = 9.2753
# Step  30: Objective = 9.5798
# Step  40: Objective = 9.7402
# Step  50: Objective = 9.7875
# Step  60: Objective = 9.8106
# Step  70: Objective = 9.8205
# Step  80: Objective = 9.8206
# Step  90: Objective = 9.7781
# Step 100: Objective = 9.7353
# Step 110: Objective = 9.7948
# Step 120: Objective = 9.8184
# Step 130: Objective = 9.8257
# Step 140: Objective = 9.8282
# Step 150: Objective = 9.8293
# Step 160: Objective = 9.8298
# Step 170: Objective = 9.8300
# Step 180: Objective = 9.8302
# Step 190: Objective = 9.8302
# Step 200: Objective = 9.8303
#
# Results:
#   Final cut: 9.83
#   Optimal cut: 10
#   Approximation ratio: 0.9830 (98.3%)
#   Time: 91.69s
#   Circuit depth: 176
#   Most frequent bitstring: 10100101
#
# ============================================================
# Graph: 10 nodes | Depth: p=1
# ============================================================
# Step  10: Objective = 10.3544
# Step  20: Objective = 10.3867
# Step  30: Objective = 10.3868
# Step  40: Objective = 10.3868
# Step  50: Objective = 10.3868
# Step  60: Objective = 10.3868
# Step  70: Objective = 10.3868
# Step  80: Objective = 10.3868
# Step  90: Objective = 10.3868
# Step 100: Objective = 10.3868
# Step 110: Objective = 10.3868
# Step 120: Objective = 10.3868
# Step 130: Objective = 10.3868
# Step 140: Objective = 10.3868
# Step 150: Objective = 10.3868
# Step 160: Objective = 10.3868
# Step 170: Objective = 10.3868
# Step 180: Objective = 10.3868
# Step 190: Objective = 10.3868
# Step 200: Objective = 10.3868
#
# Results:
#   Final cut: 10.39
#   Optimal cut: 13
#   Approximation ratio: 0.7990 (79.9%)
#   Time: 39.22s
#   Circuit depth: 55
#   Most frequent bitstring: 0111000011
#
# ============================================================
# Graph: 10 nodes | Depth: p=2
# ============================================================
# Step  10: Objective = 11.1843
# Step  20: Objective = 11.4710
# Step  30: Objective = 11.4789
# Step  40: Objective = 11.4792
# Step  50: Objective = 11.4792
# Step  60: Objective = 11.4792
# Step  70: Objective = 11.4792
# Step  80: Objective = 11.4792
# Step  90: Objective = 11.4792
# Step 100: Objective = 11.4792
# Step 110: Objective = 11.4792
# Step 120: Objective = 11.4792
# Step 130: Objective = 11.4792
# Step 140: Objective = 11.4792
# Step 150: Objective = 11.4792
# Step 160: Objective = 11.4792
# Step 170: Objective = 11.4792
# Step 180: Objective = 11.4792
# Step 190: Objective = 11.4792
# Step 200: Objective = 11.4792
#
# Results:
#   Final cut: 11.48
#   Optimal cut: 13
#   Approximation ratio: 0.8830 (88.3%)
#   Time: 72.00s
#   Circuit depth: 110
#   Most frequent bitstring: 0111000101
#
# ============================================================
# Graph: 10 nodes | Depth: p=3
# ============================================================
# Step  10: Objective = 11.2645
# Step  20: Objective = 12.0171
# Step  30: Objective = 12.1049
# Step  40: Objective = 12.1134
# Step  50: Objective = 12.1142
# Step  60: Objective = 12.1143
# Step  70: Objective = 12.1143
# Step  80: Objective = 12.1143
# Step  90: Objective = 12.1143
# Step 100: Objective = 12.1143
# Step 110: Objective = 12.1143
# Step 120: Objective = 12.1143
# Step 130: Objective = 12.1143
# Step 140: Objective = 12.1143
# Step 150: Objective = 12.1143
# Step 160: Objective = 12.1143
# Step 170: Objective = 12.1143
# Step 180: Objective = 12.1143
# Step 190: Objective = 12.1143
# Step 200: Objective = 12.1143
#
# Results:
#   Final cut: 12.11
#   Optimal cut: 13
#   Approximation ratio: 0.9319 (93.2%)
#   Time: 95.53s
#   Circuit depth: 165
#   Most frequent bitstring: 1000111010
#
# ============================================================
# Graph: 10 nodes | Depth: p=4
# ============================================================
# Step  10: Objective = 10.0486
# Step  20: Objective = 11.7674
# Step  30: Objective = 12.1414
# Step  40: Objective = 12.3307
# Step  50: Objective = 12.4566
# Step  60: Objective = 12.4872
# Step  70: Objective = 12.4920
# Step  80: Objective = 12.4928
# Step  90: Objective = 12.4929
# Step 100: Objective = 12.4929
# Step 110: Objective = 12.4929
# Step 120: Objective = 12.4929
# Step 130: Objective = 12.4929
# Step 140: Objective = 12.4929
# Step 150: Objective = 12.4929
# Step 160: Objective = 12.4929
# Step 170: Objective = 12.4929
# Step 180: Objective = 12.4929
# Step 190: Objective = 12.4929
# Step 200: Objective = 12.4929
#
# Results:
#   Final cut: 12.49
#   Optimal cut: 13
#   Approximation ratio: 0.9610 (96.1%)
#   Time: 122.03s
#   Circuit depth: 220
#   Most frequent bitstring: 1000110101
#
# ============================================================
# Graph: 12 nodes | Depth: p=1
# ============================================================
# Step  10: Objective = 12.4253
# Step  20: Objective = 12.4640
# Step  30: Objective = 12.4641
# Step  40: Objective = 12.4641
# Step  50: Objective = 12.4641
# Step  60: Objective = 12.4641
# Step  70: Objective = 12.4641
# Step  80: Objective = 12.4641
# Step  90: Objective = 12.4641
# Step 100: Objective = 12.4641
# Step 110: Objective = 12.4641
# Step 120: Objective = 12.4641
# Step 130: Objective = 12.4641
# Step 140: Objective = 12.4641
# Step 150: Objective = 12.4641
# Step 160: Objective = 12.4641
# Step 170: Objective = 12.4641
# Step 180: Objective = 12.4641
# Step 190: Objective = 12.4641
# Step 200: Objective = 12.4641
#
# Results:
#   Final cut: 12.46
#   Optimal cut: 16
#   Approximation ratio: 0.7790 (77.9%)
#   Time: 59.03s
#   Circuit depth: 66
#   Most frequent bitstring: 100011010110
#
# ============================================================
# Graph: 12 nodes | Depth: p=2
# ============================================================
# Step  10: Objective = 13.5748
# Step  20: Objective = 13.9048
# Step  30: Objective = 13.9149
# Step  40: Objective = 13.9152
# Step  50: Objective = 13.9152
# Step  60: Objective = 13.9152
# Step  70: Objective = 13.9152
# Step  80: Objective = 13.9152
# Step  90: Objective = 13.9152
# Step 100: Objective = 13.9152
# Step 110: Objective = 13.9152
# Step 120: Objective = 13.9152
# Step 130: Objective = 13.9152
# Step 140: Objective = 13.9152
# Step 150: Objective = 13.9152
# Step 160: Objective = 13.9152
# Step 170: Objective = 13.9152
# Step 180: Objective = 13.9152
# Step 190: Objective = 13.9152
# Step 200: Objective = 13.9152
#
# Results:
#   Final cut: 13.92
#   Optimal cut: 16
#   Approximation ratio: 0.8697 (87.0%)
#   Time: 100.36s
#   Circuit depth: 132
#   Most frequent bitstring: 011100101001
#
# ============================================================
# Graph: 12 nodes | Depth: p=3
# ============================================================
# Step  10: Objective = 13.3543
# Step  20: Objective = 14.5822
# Step  30: Objective = 14.6300
# Step  40: Objective = 14.7057
# Step  50: Objective = 14.7111
# Step  60: Objective = 14.7115
# Step  70: Objective = 14.7115
# Step  80: Objective = 14.7115
# Step  90: Objective = 14.7115
# Step 100: Objective = 14.7115
# Step 110: Objective = 14.7115
# Step 120: Objective = 14.7115
# Step 130: Objective = 14.7115
# Step 140: Objective = 14.7115
# Step 150: Objective = 14.7115
# Step 160: Objective = 14.7115
# Step 170: Objective = 14.7115
# Step 180: Objective = 14.7115
# Step 190: Objective = 14.7115
# Step 200: Objective = 14.7115
#
# Results:
#   Final cut: 14.71
#   Optimal cut: 16
#   Approximation ratio: 0.9195 (91.9%)
#   Time: 145.64s
#   Circuit depth: 198
#   Most frequent bitstring: 100011010110
#
# ============================================================
# Graph: 12 nodes | Depth: p=4
# ============================================================
# Step  10: Objective = 10.7993
# Step  20: Objective = 12.7117
# Step  30: Objective = 13.0679
# Step  40: Objective = 13.2056
# Step  50: Objective = 12.8895
# Step  60: Objective = 13.1408
# Step  70: Objective = 13.5759
# Step  80: Objective = 13.9031
# Step  90: Objective = 14.1161
# Step 100: Objective = 14.2404
# Step 110: Objective = 14.3082
# Step 120: Objective = 14.3447
# Step 130: Objective = 14.3649
# Step 140: Objective = 14.3769
# Step 150: Objective = 14.3848
# Step 160: Objective = 14.3905
# Step 170: Objective = 14.3949
# Step 180: Objective = 14.3984
# Step 190: Objective = 14.4013
# Step 200: Objective = 14.4038
#
# Results:
#   Final cut: 14.40
#   Optimal cut: 16
#   Approximation ratio: 0.9002 (90.0%)
#   Time: 182.48s
#   Circuit depth: 264
#   Most frequent bitstring: 011100101001
#
# ================================================================================
# SUMMARY TABLE - OBJECTIVE 1
# ================================================================================
#
# 8-node graph (Optimal cut = 10):
# --------------------------------------------------------------------------------
# p     Approx Ratio    Time (s)     Iterations   Circuit Depth
# --------------------------------------------------------------------------------
# 1     0.8309          29.96        200          44
# 2     0.9248          48.36        200          88
# 3     0.9658          66.52        200          132
# 4     0.9830          91.69        200          176
#
# 10-node graph (Optimal cut = 13):
# --------------------------------------------------------------------------------
# p     Approx Ratio    Time (s)     Iterations   Circuit Depth
# --------------------------------------------------------------------------------
# 1     0.7990          39.22        200          55
# 2     0.8830          72.00        200          110
# 3     0.9319          95.53        200          165
# 4     0.9610          122.03       200          220
#
# 12-node graph (Optimal cut = 16):
# --------------------------------------------------------------------------------
# p     Approx Ratio    Time (s)     Iterations   Circuit Depth
# --------------------------------------------------------------------------------
# 1     0.7790          59.03        200          66
# 2     0.8697          100.36       200          132
# 3     0.9195          145.64       200          198
# 4     0.9002          182.48       200          264
#
# ================================================================================

# %% [markdown]
# ### VISUALIZATION

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Plot 1: Approximation Ratio vs p
for n_wires in [8, 10, 12]:
    p_values = [1, 2, 3, 4]
    ratios = [results[n_wires][p]['approx_ratio'] for p in p_values]
    axes[0].plot(p_values, ratios, marker='o', label=f'{n_wires} nodes', linewidth=2)

axes[0].set_xlabel('Circuit Depth (p)', fontsize=12)
axes[0].set_ylabel('Approximation Ratio', fontsize=12)
axes[0].set_title('Approximation Ratio vs Depth', fontsize=13, fontweight='bold')
axes[0].legend()
axes[0].grid(True, alpha=0.3)
axes[0].set_xticks([1, 2, 3, 4])

# Plot 2: Time vs p
for n_wires in [8, 10, 12]:
    p_values = [1, 2, 3, 4]
    times = [results[n_wires][p]['time'] for p in p_values]
    axes[1].plot(p_values, times, marker='s', label=f'{n_wires} nodes', linewidth=2)

axes[1].set_xlabel('Circuit Depth (p)', fontsize=12)
axes[1].set_ylabel('Computation Time (s)', fontsize=12)
axes[1].set_title('Computation Time vs Depth', fontsize=13, fontweight='bold')
axes[1].legend()
axes[1].grid(True, alpha=0.3)
axes[1].set_xticks([1, 2, 3, 4])

# Plot 3: Circuit Depth vs p
for n_wires in [8, 10, 12]:
    p_values = [1, 2, 3, 4]
    depths = [results[n_wires][p]['circuit_depth'] for p in p_values]
    axes[2].plot(p_values, depths, marker='^', label=f'{n_wires} nodes', linewidth=2)

axes[2].set_xlabel('Circuit Depth (p)', fontsize=12)
axes[2].set_ylabel('Gate Depth', fontsize=12)
axes[2].set_title('Circuit Gate Depth vs p', fontsize=13, fontweight='bold')
axes[2].legend()
axes[2].grid(True, alpha=0.3)
axes[2].set_xticks([1, 2, 3, 4])

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 4, figsize=(16, 10))

for i, n_wires in enumerate([8, 10, 12]):
    for j, n_layers in enumerate([1, 2, 3, 4]):
        ax = axes[i, j]
        
        samples = results[n_wires][n_layers]['bitstrings']
        max_int = 2**n_wires - 1
        bins = np.arange(0, max_int + 2) - 0.5
        
        ax.hist(samples, bins=bins, edgecolor='black', alpha=0.7)
        ax.set_title(f'{n_wires} nodes, p={n_layers}', fontsize=10, fontweight='bold')
        ax.set_xlabel('Bitstring (int)', fontsize=8)
        ax.set_ylabel('Frequency', fontsize=8)
        ax.tick_params(labelsize=7)
        ax.grid(True, alpha=0.3, axis='y')

plt.tight_layout()
plt.show()


# FINAL SUMMARY

print("OBJECTIVE 01: ")

for n_wires in [8, 10, 12]:
    print(f"\n{n_wires}-node graph:")
    for p in [1, 2, 3, 4]:
        r = results[n_wires][p]
        print(f"  p={p}: {r['approx_ratio']:.1%} ratio, {r['time']:.1f}s, depth={r['circuit_depth']}")
# Out:
# OBJECTIVE 01:
#
# 8-node graph:
#   p=1: 77.8% ratio, 13.3s, depth=44
#   p=2: 83.7% ratio, 22.0s, depth=88
#   p=3: 86.4% ratio, 33.0s, depth=132
#   p=4: 88.7% ratio, 42.0s, depth=176
#
# 10-node graph:
#   p=1: 69.2% ratio, 17.5s, depth=55
#   p=2: 79.2% ratio, 29.8s, depth=110
#   p=3: 82.8% ratio, 42.4s, depth=165
#   p=4: 95.2% ratio, 54.2s, depth=220
#
# 12-node graph:
#   p=1: 77.6% ratio, 26.1s, depth=66
#   p=2: 85.9% ratio, 45.1s, depth=132
#   p=3: 91.2% ratio, 63.3s, depth=198
#   p=4: 94.2% ratio, 82.7s, depth=264

# %% [markdown]
# ## Higher p → better quality BUT more time + deeper circuits

# %%
import pennylane as qml
print(qml.__version__)
# Out:
# 0.44.0
# C:\Users\Probook\anaconda3\Lib\site-packages\pennylane\__init__.py:212: PennyLaneDeprecationWarning: PennyLane v0.44 has dropped maintainence support for NumPy < 2.0.0. You have version 1.26.4 installed. Future versions of PennyLane will not work with NumPy<2.0. Please consider upgrading NumPy using `python -m pip install numpy --upgrade`.
#   warnings.warn(

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.26.4

# %%
import networkx as nx
print(nx.__version__)
# Out:
# 3.1

# %%
from scipy.optimize import minimize

results = {}
# Loop over 3 graphs
for n_wires in [8, 10, 12]:
    graph = graphs[n_wires]
    optimal_cut = optimal_cuts[n_wires]
    
    results[n_wires] = {}
    
    # Create device for this graph size
    dev = qml.device("default.qubit", wires=n_wires)
    
    # Define circuit for this graph
    @qml.qnode(dev)
    def circuit(gammas, betas, return_samples=False):
        for wire in range(n_wires):
            qml.Hadamard(wires=wire)
        
        for gamma, beta in zip(gammas, betas):
            U_C(gamma, graph)
            U_M(beta, n_wires)
        
        if return_samples:
            return qml.sample()
        
        C = qml.sum(*(qml.Z(w1) @ qml.Z(w2) for w1, w2 in graph))
        return qml.expval(C)
    
    def objective(params):
        return -0.5 * (len(graph) - circuit(*params))
    
    # Loop over 4 depths: p=1,2,3,4
    for n_layers in [1, 2, 3, 4]:
        print(f"\n{'='*60}")
        print(f"Graph: {n_wires} nodes | Depth: p={n_layers}")
        print(f"{'='*60}")
        
        # Initialize parameters
        np.random.seed(42)
        init_params = np.random.uniform(
            0, 2*np.pi,
            2*n_layers
        )
        
        # Start timing
        start_time = time.time()
        
        # Optimize with COBYLA
        steps = 200
        iteration_count = [0]

        def objective_flat(params_flat):
            gammas = params_flat[:n_layers]
            betas  = params_flat[n_layers:]
            result = -0.5 * (len(graph) - circuit(gammas, betas))
            iteration_count[0] += 1
            if iteration_count[0] % 10 == 0:
                print(f"Step {iteration_count[0]:3d}: "
                      f"Objective = {-result:.4f}")
            return result

        opt_result = minimize(
            objective_flat,
            init_params,
            method='COBYLA',
            options={
                'maxiter': steps,
                'rhobeg': 0.5
            }
        )
        
        # End timing
        elapsed_time = time.time() - start_time
        
        # Extract optimized parameters
        best_params_flat = opt_result.x
        gammas = best_params_flat[:n_layers]
        betas  = best_params_flat[n_layers:]
        
        # Get final cut value
        final_cut = -objective_flat(best_params_flat)
        
        # Calculate approximation ratio
        approx_ratio = final_cut / optimal_cut
        
        # Get circuit depth (estimate)
        circuit_depth = n_layers * (3 * len(graph) + n_wires)
        
        # Sample bitstrings with optimized parameters
        bitstrings = qml.set_shots(circuit, shots=100)(
            gammas, betas, return_samples=True
        )
        sampled_ints = [bitstring_to_int(string) for string in bitstrings]
        
        # Find most frequent bitstring
        counts = np.bincount(np.array(sampled_ints))
        most_freq_bit_string = np.argmax(counts)
        
        # Store results
        results[n_wires][n_layers] = {
            'approx_ratio': approx_ratio,
            'iterations': iteration_count[0],
            'time': elapsed_time,
            'circuit_depth': circuit_depth,
            'final_cut': final_cut,
            'optimal_cut': optimal_cut,
            'params': (gammas, betas),
            'bitstrings': sampled_ints,
            'most_frequent': most_freq_bit_string
        }
        
        # Print summary
        print(f"\nResults:")
        print(f"  Final cut: {final_cut:.2f}")
        print(f"  Optimal cut: {optimal_cut}")
        print(f"  Approximation ratio: {approx_ratio:.4f} "
              f"({approx_ratio*100:.1f}%)")
        print(f"  Time: {elapsed_time:.2f}s")
        print(f"  Circuit depth: {circuit_depth}")
        print(f"  Most frequent bitstring: "
              f"{most_freq_bit_string:0{n_wires}b}")

# RESULTS SUMMARY TABLE
print("\n" + "="*80)
print("SUMMARY TABLE - OBJECTIVE 1")
print("="*80)
for n_wires in [8, 10, 12]:
    print(f"\n{n_wires}-node graph "
          f"(Optimal cut = {optimal_cuts[n_wires]}):")
    print("-"*80)
    print(f"{'p':<5} {'Approx Ratio':<15} {'Time (s)':<12} "
          f"{'Iterations':<12} {'Circuit Depth':<15}")
    print("-"*80)
    
    for n_layers in [1, 2, 3, 4]:
        r = results[n_wires][n_layers]
        print(f"{n_layers:<5} {r['approx_ratio']:<15.4f} "
              f"{r['time']:<12.2f} {r['iterations']:<12} "
              f"{r['circuit_depth']:<15}")

print("\n" + "="*80)
# Out:
# ============================================================
# Graph: 8 nodes | Depth: p=1
# ============================================================
# Step  10: Objective = 8.1931
# Step  20: Objective = 8.3094
# Step  30: Objective = 8.3094
#
# Results:
#   Final cut: 8.31
#   Optimal cut: 10
#   Approximation ratio: 0.8309 (83.1%)
#   Time: 0.62s
#   Circuit depth: 44
#   Most frequent bitstring: 01110001
#
# ============================================================
# Graph: 8 nodes | Depth: p=2
# ============================================================
# Step  10: Objective = 7.4413
# Step  20: Objective = 9.1339
# Step  30: Objective = 9.1687
# Step  40: Objective = 9.1866
# Step  50: Objective = 9.1910
# Step  60: Objective = 9.1958
# Step  70: Objective = 9.1970
# Step  80: Objective = 9.1979
# Step  90: Objective = 9.1991
# Step 100: Objective = 9.1999
# Step 110: Objective = 9.2006
# Step 120: Objective = 9.2012
# Step 130: Objective = 9.2014
# Step 140: Objective = 9.2015
# Step 150: Objective = 9.2015
# Step 160: Objective = 9.2016
# Step 170: Objective = 9.2016
# Step 180: Objective = 9.2016
# Step 190: Objective = 9.2016
# Step 200: Objective = 9.2016
#
# Results:
#   Final cut: 9.20
#   Optimal cut: 10
#   Approximation ratio: 0.9202 (92.0%)
#   Time: 6.84s
#   Circuit depth: 88
#   Most frequent bitstring: 10001101
#
# ============================================================
# Graph: 8 nodes | Depth: p=3
# ============================================================
# Step  10: Objective = 6.8718
# Step  20: Objective = 8.3397
# Step  30: Objective = 8.8627
# Step  40: Objective = 9.1761
# Step  50: Objective = 9.2976
# Step  60: Objective = 9.4111
# Step  70: Objective = 9.4258
# Step  80: Objective = 9.4330
# Step  90: Objective = 9.4353
# Step 100: Objective = 9.4371
# Step 110: Objective = 9.4386
# Step 120: Objective = 9.4402
# Step 130: Objective = 9.4411
# Step 140: Objective = 9.4428
# Step 150: Objective = 9.4434
# Step 160: Objective = 9.4449
# Step 170: Objective = 9.4458
# Step 180: Objective = 9.4464
# Step 190: Objective = 9.4471
# Step 200: Objective = 9.4478
#
# Results:
#   Final cut: 9.45
#   Optimal cut: 10
#   Approximation ratio: 0.9448 (94.5%)
#   Time: 8.01s
#   Circuit depth: 132
#   Most frequent bitstring: 01110001
#
# ============================================================
# Graph: 8 nodes | Depth: p=4
# ============================================================
# Step  10: Objective = 8.5656
# Step  20: Objective = 9.4202
# Step  30: Objective = 9.3764
# Step  40: Objective = 9.4478
# Step  50: Objective = 9.5249
# Step  60: Objective = 9.5505
# Step  70: Objective = 9.6027
# Step  80: Objective = 9.6418
# Step  90: Objective = 9.6647
# Step 100: Objective = 9.6973
# Step 110: Objective = 9.7124
# Step 120: Objective = 9.7151
# Step 130: Objective = 9.7289
# Step 140: Objective = 9.7331
# Step 150: Objective = 9.7345
# Step 160: Objective = 9.7361
# Step 170: Objective = 9.7375
# Step 180: Objective = 9.7386
# Step 190: Objective = 9.7393
# Step 200: Objective = 9.7396
#
# Results:
#   Final cut: 9.74
#   Optimal cut: 10
#   Approximation ratio: 0.9740 (97.4%)
#   Time: 10.02s
#   Circuit depth: 176
#   Most frequent bitstring: 01110001
#
# ============================================================
# Graph: 10 nodes | Depth: p=1
# ============================================================
# Step  10: Objective = 10.2414
# Step  20: Objective = 10.3867
# Step  30: Objective = 10.3868
#
# Results:
#   Final cut: 10.39
#   Optimal cut: 13
#   Approximation ratio: 0.7990 (79.9%)
#   Time: 0.71s
#   Circuit depth: 55
#   Most frequent bitstring: 0111000101
#
# ============================================================
# Graph: 10 nodes | Depth: p=2
# ============================================================
# Step  10: Objective = 9.2979
# Step  20: Objective = 11.1807
# Step  30: Objective = 11.3418
# Step  40: Objective = 11.3614
# Step  50: Objective = 11.3641
# Step  60: Objective = 11.3667
# Step  70: Objective = 11.3689
# Step  80: Objective = 11.3704
# Step  90: Objective = 11.3715
# Step 100: Objective = 11.3719
# Step 110: Objective = 11.3722
# Step 120: Objective = 11.3723
# Step 130: Objective = 11.3724
# Step 140: Objective = 11.3724
# Step 150: Objective = 11.3725
# Step 160: Objective = 11.3725
# Step 170: Objective = 11.3726
# Step 180: Objective = 11.3726
# Step 190: Objective = 11.3726
# Step 200: Objective = 11.3726
#
# Results:
#   Final cut: 11.37
#   Optimal cut: 13
#   Approximation ratio: 0.8748 (87.5%)
#   Time: 7.66s
#   Circuit depth: 110
#   Most frequent bitstring: 0111000101
#
# ============================================================
# Graph: 10 nodes | Depth: p=3
# ============================================================
# Step  10: Objective = 8.5085
# Step  20: Objective = 11.2033
# Step  30: Objective = 11.6082
# Step  40: Objective = 11.7158
# Step  50: Objective = 11.7454
# Step  60: Objective = 11.7467
# Step  70: Objective = 11.7483
# Step  80: Objective = 11.7492
# Step  90: Objective = 11.7500
# Step 100: Objective = 11.7509
# Step 110: Objective = 11.7524
# Step 120: Objective = 11.7532
# Step 130: Objective = 11.7541
# Step 140: Objective = 11.7549
# Step 150: Objective = 11.7560
# Step 160: Objective = 11.7565
# Step 170: Objective = 11.7574
# Step 180: Objective = 11.7583
# Step 190: Objective = 11.7591
# Step 200: Objective = 11.7594
#
# Results:
#   Final cut: 11.76
#   Optimal cut: 13
#   Approximation ratio: 0.9046 (90.5%)
#   Time: 9.93s
#   Circuit depth: 165
#   Most frequent bitstring: 1000111010
#
# ============================================================
# Graph: 10 nodes | Depth: p=4
# ============================================================
# Step  10: Objective = 10.6581
# Step  20: Objective = 11.5688
# Step  30: Objective = 12.0227
# Step  40: Objective = 12.1062
# Step  50: Objective = 12.1598
# Step  60: Objective = 12.1873
# Step  70: Objective = 12.2160
# Step  80: Objective = 12.2317
# Step  90: Objective = 12.2520
# Step 100: Objective = 12.2634
# Step 110: Objective = 12.2723
# Step 120: Objective = 12.2739
# Step 130: Objective = 12.2779
# Step 140: Objective = 12.2803
# Step 150: Objective = 12.2818
# Step 160: Objective = 12.2829
# Step 170: Objective = 12.2829
# Step 180: Objective = 12.2837
# Step 190: Objective = 12.2842
# Step 200: Objective = 12.2844
#
# Results:
#   Final cut: 12.28
#   Optimal cut: 13
#   Approximation ratio: 0.9450 (94.5%)
#   Time: 13.20s
#   Circuit depth: 220
#   Most frequent bitstring: 0111000101
#
# ============================================================
# Graph: 12 nodes | Depth: p=1
# ============================================================
# Step  10: Objective = 12.2897
# Step  20: Objective = 12.4639
# Step  30: Objective = 12.4641
#
# Results:
#   Final cut: 12.46
#   Optimal cut: 16
#   Approximation ratio: 0.7790 (77.9%)
#   Time: 0.92s
#   Circuit depth: 66
#   Most frequent bitstring: 011100010110
#
# ============================================================
# Graph: 12 nodes | Depth: p=2
# ============================================================
# Step  10: Objective = 11.1869
# Step  20: Objective = 13.2596
# Step  30: Objective = 13.6855
# Step  40: Objective = 13.7197
# Step  50: Objective = 13.7273
# Step  60: Objective = 13.7333
# Step  70: Objective = 13.7380
# Step  80: Objective = 13.7405
# Step  90: Objective = 13.7428
# Step 100: Objective = 13.7446
# Step 110: Objective = 13.7454
# Step 120: Objective = 13.7456
# Step 130: Objective = 13.7458
# Step 140: Objective = 13.7461
# Step 150: Objective = 13.7461
# Step 160: Objective = 13.7462
# Step 170: Objective = 13.7463
# Step 180: Objective = 13.7463
# Step 190: Objective = 13.7463
# Step 200: Objective = 13.7463
#
# Results:
#   Final cut: 13.75
#   Optimal cut: 16
#   Approximation ratio: 0.8591 (85.9%)
#   Time: 10.35s
#   Circuit depth: 132
#   Most frequent bitstring: 011100010110
#
# ============================================================
# Graph: 12 nodes | Depth: p=3
# ============================================================
# Step  10: Objective = 9.5910
# Step  20: Objective = 13.6597
# Step  30: Objective = 13.9797
# Step  40: Objective = 14.1244
# Step  50: Objective = 14.1476
# Step  60: Objective = 14.1542
# Step  70: Objective = 14.1606
# Step  80: Objective = 14.1645
# Step  90: Objective = 14.1694
# Step 100: Objective = 14.1702
# Step 110: Objective = 14.1725
# Step 120: Objective = 14.1735
# Step 130: Objective = 14.1744
# Step 140: Objective = 14.1751
# Step 150: Objective = 14.1754
# Step 160: Objective = 14.1756
# Step 170: Objective = 14.1756
# Step 180: Objective = 14.1757
# Step 190: Objective = 14.1757
# Step 200: Objective = 14.1758
#
# Results:
#   Final cut: 14.18
#   Optimal cut: 16
#   Approximation ratio: 0.8860 (88.6%)
#   Time: 14.31s
#   Circuit depth: 198
#   Most frequent bitstring: 100011101001
#
# ============================================================
# Graph: 12 nodes | Depth: p=4
# ============================================================
# Step  10: Objective = 12.8047
# Step  20: Objective = 14.1082
# Step  30: Objective = 14.5151
# Step  40: Objective = 14.6379
# Step  50: Objective = 14.7657
# Step  60: Objective = 14.8009
# Step  70: Objective = 14.8358
# Step  80: Objective = 14.8502
# Step  90: Objective = 14.8689
# Step 100: Objective = 14.8805
# Step 110: Objective = 14.8870
# Step 120: Objective = 14.8986
# Step 130: Objective = 14.9040
# Step 140: Objective = 14.9058
# Step 150: Objective = 14.9073
# Step 160: Objective = 14.9077
# Step 170: Objective = 14.9078
# Step 180: Objective = 14.9080
# Step 190: Objective = 14.9080
# Step 200: Objective = 14.9081
#
# Results:
#   Final cut: 14.91
#   Optimal cut: 16
#   Approximation ratio: 0.9318 (93.2%)
#   Time: 18.31s
#   Circuit depth: 264
#   Most frequent bitstring: 100011010110
#
# ================================================================================
# SUMMARY TABLE - OBJECTIVE 1
# ================================================================================
#
# 8-node graph (Optimal cut = 10):
# --------------------------------------------------------------------------------
# p     Approx Ratio    Time (s)     Iterations   Circuit Depth
# --------------------------------------------------------------------------------
# 1     0.8309          0.62         34           44
# 2     0.9202          6.84         201          88
# 3     0.9448          8.01         201          132
# 4     0.9740          10.02        201          176
#
# 10-node graph (Optimal cut = 13):
# --------------------------------------------------------------------------------
# p     Approx Ratio    Time (s)     Iterations   Circuit Depth
# --------------------------------------------------------------------------------
# 1     0.7990          0.71         34           55
# 2     0.8748          7.66         201          110
# 3     0.9046          9.93         201          165
# 4     0.9450          13.20        201          220
#
# 12-node graph (Optimal cut = 16):
# --------------------------------------------------------------------------------
# p     Approx Ratio    Time (s)     Iterations   Circuit Depth
# --------------------------------------------------------------------------------
# 1     0.7790          0.92         31           66
# 2     0.8591          10.35        201          132
# 3     0.8860          14.31        201          198
# 4     0.9318          18.31        201          264
#
# ================================================================================

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Plot 1: Approximation Ratio vs p
for n_wires in [8, 10, 12]:
    p_values = [1, 2, 3, 4]
    ratios = [results[n_wires][p]['approx_ratio'] for p in p_values]
    axes[0].plot(p_values, ratios, marker='o', label=f'{n_wires} nodes', linewidth=2)

axes[0].set_xlabel('Circuit Depth (p)', fontsize=12)
axes[0].set_ylabel('Approximation Ratio', fontsize=12)
axes[0].set_title('Approximation Ratio vs Depth', fontsize=13, fontweight='bold')
axes[0].legend()
axes[0].grid(True, alpha=0.3)
axes[0].set_xticks([1, 2, 3, 4])

# Plot 2: Time vs p
for n_wires in [8, 10, 12]:
    p_values = [1, 2, 3, 4]
    times = [results[n_wires][p]['time'] for p in p_values]
    axes[1].plot(p_values, times, marker='s', label=f'{n_wires} nodes', linewidth=2)

axes[1].set_xlabel('Circuit Depth (p)', fontsize=12)
axes[1].set_ylabel('Computation Time (s)', fontsize=12)
axes[1].set_title('Computation Time vs Depth', fontsize=13, fontweight='bold')
axes[1].legend()
axes[1].grid(True, alpha=0.3)
axes[1].set_xticks([1, 2, 3, 4])

# Plot 3: Circuit Depth vs p
for n_wires in [8, 10, 12]:
    p_values = [1, 2, 3, 4]
    depths = [results[n_wires][p]['circuit_depth'] for p in p_values]
    axes[2].plot(p_values, depths, marker='^', label=f'{n_wires} nodes', linewidth=2)

axes[2].set_xlabel('Circuit Depth (p)', fontsize=12)
axes[2].set_ylabel('Gate Depth', fontsize=12)
axes[2].set_title('Circuit Gate Depth vs p', fontsize=13, fontweight='bold')
axes[2].legend()
axes[2].grid(True, alpha=0.3)
axes[2].set_xticks([1, 2, 3, 4])

plt.tight_layout()
plt.show()
