# %%
import pennylane as qml 
from pennylane import numpy as np 
import time 
from scipy.optimize import minimize
import matplotlib.pyplot as plt 
import networkx as nx 

np.random.seed(42)
# Out:
# C:\Users\Probook\anaconda3\Lib\site-packages\pennylane\__init__.py:212: PennyLaneDeprecationWarning: PennyLane v0.44 has dropped maintainence support for NumPy < 2.0.0. You have version 1.26.4 installed. Future versions of PennyLane will not work with NumPy<2.0. Please consider upgrading NumPy using `python -m pip install numpy --upgrade`.
#   warnings.warn(

# %%
graphs = {
     8: [(0,1),(0,2),(0,4),(0,6),(1,3),(1,5),(2,3),
        (2,7),(3,6),(4,5),(4,7),(5,6),(6,7)],
    10: [(0,1),(0,3),(0,5),(0,7),(1,2),(1,4),(1,6),
         (2,3),(2,8),(3,9),(4,5),(4,8),(5,9),
         (6,7),(6,9),(7,8),(8,9)],
    12: [(0,1),(0,3),(0,5),(0,7),(0,9),(1,2),(1,4),
         (1,6),(2,3),(2,8),(2,10),(3,9),(3,11),(4,5),
         (4,8),(5,9),(5,11),(6,7),(6,10),(7,8),(7,11),
         (8,9),(10,11)]
}





fig, axes = plt.subplots(1, 3, figsize=(15, 4))

for idx, n_wires in enumerate([8, 10, 12]):
    ax = axes[idx]
    
    # Create NetworkX graph
    G = nx.Graph()
    G.add_edges_from(graphs[n_wires])
    
    # Layout
    pos = nx.spring_layout(G, seed=42, k=1.5)
    
    # Draw
    nx.draw_networkx_nodes(G, pos, node_color='lightblue', 
                           node_size=500, edgecolors='black', 
                           linewidths=2, ax=ax)
    nx.draw_networkx_labels(G, pos, font_size=10, 
                            font_weight='bold', ax=ax)
    nx.draw_networkx_edges(G, pos, edge_color='gray', 
                           width=2, ax=ax)
    
    ax.set_title(f'{n_wires}-Node Graph ({len(graphs[n_wires])} edges)', 
                 fontsize=13, fontweight='bold')
    ax.axis('off')

plt.tight_layout()
plt.show()

print()

# %%
def compute_optimal_cut(n_wires, graph):
    """Brute force search for optimal MaxCut"""
    best_cut = 0
    
    for partition in range(2**n_wires):
        # Convert partition number to bitstring
        bitstring = format(partition, f'0{n_wires}b')
        
        # Count cut edges
        cut = 0
        for edge in graph:
            if bitstring[edge[0]] != bitstring[edge[1]]:
                cut += 1
        
        if cut > best_cut:
            best_cut = cut
    
    return best_cut

# Calculate optimal cuts for all graphs
optimal_cuts = {}
print("Calculating optimal cuts")
for n_wires, graph in graphs.items():
    optimal_cuts[n_wires] = compute_optimal_cut(n_wires, graph)
    print(f"  {n_wires}-node graph: Optimal cut = {optimal_cuts[n_wires]}")

print()
# Out:
# Calculating optimal cuts
#   8-node graph: Optimal cut = 13
#   10-node graph: Optimal cut = 15
#   12-node graph: Optimal cut = 21

# %%
def U_B(beta, n_wires):
    for wire in range(n_wires):
        qml.RX(2 * beta, wires=wire)

def U_C(gamma, graph):
    for edge in graph:
        qml.CNOT(wires=edge)
        qml.RZ(gamma, wires=edge[1])
        qml.CNOT(wires=edge)

# %%
def random_init(p, seed=None):
    """Random initialization between 0 and 2π"""
    if seed is not None:
        np.random.seed(seed)
    return np.random.uniform(0, 2*np.pi, 2*p)

def fixed_init(p):
    """Fixed initialization at 1.0"""
    return np.ones(2*p)

def tqa_init(p):
    """TQA-inspired: gamma increases, beta decreases"""
    gammas = np.linspace(0.1, 1.0, p)
    betas = np.linspace(0.5, 0.1, p)
    return np.concatenate([gammas, betas])

def warm_start_init(p, prev_optimal):
    """Warm-start: interpolate from p-1 optimal parameters"""
    if p == 1 or prev_optimal is None:
        # No previous solution, use random
        return random_init(p)
    
    # Previous params: [γ₁*, ..., γₚ₋₁*, β₁*, ..., βₚ₋₁*]
    prev_p = len(prev_optimal) // 2
    prev_gammas = prev_optimal[:prev_p]
    prev_betas = prev_optimal[prev_p:]
    
    # Interpolate to p layers
    # Simple strategy: repeat last values and add small perturbation
    new_gammas = np.zeros(p)
    new_betas = np.zeros(p)
    
    for i in range(p):
        idx = min(i, prev_p - 1)
        new_gammas[i] = prev_gammas[idx]
        new_betas[i] = prev_betas[idx]
    
    # Add small random perturbation
    new_gammas += np.random.normal(0, 0.05, p)
    new_betas += np.random.normal(0, 0.05, p)
    
    return np.concatenate([new_gammas, new_betas])

# %%
n_trials = 10  # Trials per strategy
max_iter = 300

# Store optimal parameters for warm-start
optimal_params_storage = {}

strategies = {
    'Random': ('random', random_init),
    'Fixed': ('deterministic', fixed_init),
    'TQA': ('deterministic', tqa_init),
    'Warm-Start': ('warm', warm_start_init)
}

results = {}

for n_wires in [8, 10, 12]:
    graph = graphs[n_wires]
    optimal_cut = optimal_cuts[n_wires]
    
    results[n_wires] = {}
    optimal_params_storage[n_wires] = {}
    
    # Create device
    dev = qml.device("default.qubit", wires=n_wires)
    
    # Define circuit
    @qml.qnode(dev)
    def circuit(params, p):
        params_2d = params.reshape(2, p)
        gammas = params_2d[0]
        betas = params_2d[1]
        
        for wire in range(n_wires):
            qml.Hadamard(wires=wire)
        
        for gamma, beta in zip(gammas, betas):
            U_C(gamma, graph)
            U_B(beta, n_wires)
        
        C = qml.sum(*(qml.Z(w1) @ qml.Z(w2) for w1, w2 in graph))
        return qml.expval(C)
    
    def objective(params, p):
        return -0.5 * (len(graph) - circuit(params, p))
    
    # Test each depth
    for p in [1, 2]:
        print(f"\n{'='*70}")
        print(f"Graph: {n_wires} nodes | Depth: p={p}")
        print(f"{'='*70}")
        
        results[n_wires][p] = {}
        
        # ---- CHANGED: track best across ALL strategies ----
        best_ratio_this_p = 0
        best_params_this_p = None
        # ---------------------------------------------------
        
        # Test each strategy
        for strategy_name, (strategy_type, init_func) in strategies.items():
            print(f"\n  Strategy: {strategy_name}")
            
            results[n_wires][p][strategy_name] = []
            
            # Determine number of trials
            if strategy_type == 'deterministic':
                trials = 1
            else:
                trials = n_trials
            
            for trial in range(trials):
                if trials > 1:
                    print(f"    Trial {trial + 1}/{trials}", end=" ")
                
                # Initialize parameters
                if strategy_name == 'Warm-Start':
                    prev_optimal = optimal_params_storage[n_wires].get(p-1, None)
                    init_params = init_func(p, prev_optimal)
                elif strategy_type == 'random':
                    init_params = init_func(p, seed=trial*10)
                else:
                    init_params = init_func(p)
                
                # Track convergence
                convergence_history = {'iteration': [], 'cost': [], 'time': []}
                iteration_count = [0]
                start_time = time.time()
                
                def callback(params):
                    iteration_count[0] += 1
                    current_time = time.time() - start_time
                    cost = objective(params, p)
                    
                    convergence_history['iteration'].append(iteration_count[0])
                    convergence_history['cost'].append(cost)
                    convergence_history['time'].append(current_time)
                
                # Optimize using L-BFGS-B
                opt_start = time.time()
                result = minimize(
                    lambda params: objective(params, p),
                    init_params,
                    method='L-BFGS-B',
                    callback=callback,
                    options={'maxiter': max_iter}
                )
                opt_time = time.time() - opt_start
                
                # Final results
                final_cut = -objective(result.x, p)
                approx_ratio = final_cut / optimal_cut
                
                # Convergence speed: iterations to 95% of final
                target_cost = result.fun * 0.95
                convergence_iter = next(
                    (i for i, cost in enumerate(convergence_history['cost']) 
                     if cost <= target_cost), 
                    len(convergence_history['cost'])
                )
                
                # Time to 95%
                time_to_95 = convergence_history['time'][convergence_iter] if convergence_iter < len(convergence_history['time']) else opt_time
                
                # Success: did it reach 90% approximation ratio?
                success = approx_ratio >= 0.90
                
                # Store trial results
                trial_result = {
                    'approx_ratio': approx_ratio,
                    'final_cut': final_cut,
                    'time': opt_time,
                    'iterations': result.nfev,
                    'convergence_iter': convergence_iter,
                    'time_to_95': time_to_95,
                    'success': success,
                    'convergence_history': convergence_history,
                    'final_params': result.x,
                    'init_params': init_params
                }
                
                results[n_wires][p][strategy_name].append(trial_result)
                
                if trials > 1:
                    print(f"- Ratio: {approx_ratio:.3f}, Time: {opt_time:.1f}s, Iters: {result.nfev}")
                else:
                    print(f"    Ratio: {approx_ratio:.4f}, Time: {opt_time:.2f}s, Iterations: {result.nfev}")
                
                # ---- CHANGED: track best params across ALL strategies ----
                if approx_ratio > best_ratio_this_p:
                    best_ratio_this_p = approx_ratio
                    best_params_this_p = result.x.copy()
                # ----------------------------------------------------------
        
        # ---- CHANGED: store best params from ALL strategies for warm-start ----
        optimal_params_storage[n_wires][p] = best_params_this_p
        # -----------------------------------------------------------------------
# Out:
# ======================================================================
# Graph: 8 nodes | Depth: p=1
# ======================================================================
#
#   Strategy: Random
# - Ratio: 0.586, Time: 1.0s, Iters: 45
# - Ratio: 0.682, Time: 0.6s, Iters: 30
# - Ratio: 0.586, Time: 0.6s, Iters: 27
# - Ratio: 0.586, Time: 0.6s, Iters: 30
# - Ratio: 0.586, Time: 0.9s, Iters: 45
# - Ratio: 0.586, Time: 0.6s, Iters: 30
# - Ratio: 0.586, Time: 0.5s, Iters: 24
# - Ratio: 0.682, Time: 0.5s, Iters: 24
# - Ratio: 0.586, Time: 0.6s, Iters: 30
# - Ratio: 0.682, Time: 0.7s, Iters: 33
#
#   Strategy: Fixed
#     Ratio: 0.6821, Time: 0.62s, Iterations: 30
#
#   Strategy: TQA
#     Ratio: 0.6821, Time: 0.63s, Iterations: 30
#
#   Strategy: Warm-Start
# - Ratio: 0.682, Time: 2.8s, Iters: 42
# - Ratio: 0.586, Time: 2.7s, Iters: 57
# - Ratio: 0.586, Time: 1.8s, Iters: 33
# - Ratio: 0.586, Time: 2.2s, Iters: 45
# - Ratio: 0.586, Time: 1.4s, Iters: 27
# - Ratio: 0.586, Time: 1.4s, Iters: 27
# - Ratio: 0.586, Time: 1.3s, Iters: 24
# - Ratio: 0.682, Time: 1.8s, Iters: 36
# - Ratio: 0.586, Time: 1.8s, Iters: 33
# - Ratio: 0.586, Time: 1.8s, Iters: 24
#
# ======================================================================
# Graph: 8 nodes | Depth: p=2
# ======================================================================
#
#   Strategy: Random
# - Ratio: 0.616, Time: 4.5s, Iters: 130
# - Ratio: 0.595, Time: 6.7s, Iters: 210
# - Ratio: 0.616, Time: 4.5s, Iters: 145
# - Ratio: 0.694, Time: 3.0s, Iters: 95
# - Ratio: 0.595, Time: 6.3s, Iters: 200
# - Ratio: 0.711, Time: 2.3s, Iters: 75
# - Ratio: 0.595, Time: 3.5s, Iters: 110
# - Ratio: 0.823, Time: 2.2s, Iters: 70
# - Ratio: 0.686, Time: 2.6s, Iters: 80
# - Ratio: 0.700, Time: 4.5s, Iters: 145
#
#   Strategy: Fixed
#     Ratio: 0.8228, Time: 2.35s, Iterations: 75
#
#   Strategy: TQA
#     Ratio: 0.7605, Time: 3.01s, Iterations: 95
#
#   Strategy: Warm-Start
# - Ratio: 0.823, Time: 1.7s, Iters: 55
# - Ratio: 0.823, Time: 1.8s, Iters: 55
# - Ratio: 0.823, Time: 1.6s, Iters: 50
# - Ratio: 0.823, Time: 1.7s, Iters: 50
# - Ratio: 0.823, Time: 1.7s, Iters: 50
# - Ratio: 0.823, Time: 1.7s, Iters: 55
# - Ratio: 0.823, Time: 1.6s, Iters: 50
# - Ratio: 0.823, Time: 1.6s, Iters: 50
# - Ratio: 0.823, Time: 1.4s, Iters: 45
# - Ratio: 0.823, Time: 1.7s, Iters: 55
#
# ======================================================================
# Graph: 10 nodes | Depth: p=1
# ======================================================================
#
#   Strategy: Random
# - Ratio: 0.767, Time: 2.0s, Iters: 75
# - Ratio: 0.767, Time: 0.8s, Iters: 30
# - Ratio: 0.607, Time: 1.2s, Iters: 45
# - Ratio: 0.607, Time: 0.6s, Iters: 24
# - Ratio: 0.607, Time: 1.2s, Iters: 42
# - Ratio: 0.607, Time: 0.8s, Iters: 30
# - Ratio: 0.607, Time: 0.6s, Iters: 21
# - Ratio: 0.767, Time: 0.7s, Iters: 24
# - Ratio: 0.607, Time: 0.7s, Iters: 27
# - Ratio: 0.767, Time: 0.8s, Iters: 30
#
#   Strategy: Fixed
#     Ratio: 0.7673, Time: 0.83s, Iterations: 30
#
#   Strategy: TQA
#     Ratio: 0.7673, Time: 0.90s, Iterations: 30
#
#   Strategy: Warm-Start
# - Ratio: 0.767, Time: 1.2s, Iters: 42
# - Ratio: 0.607, Time: 1.5s, Iters: 54
# - Ratio: 0.607, Time: 0.7s, Iters: 24
# - Ratio: 0.767, Time: 1.8s, Iters: 66
# - Ratio: 0.607, Time: 1.0s, Iters: 33
# - Ratio: 0.607, Time: 0.6s, Iters: 24
# - Ratio: 0.607, Time: 0.9s, Iters: 27
# - Ratio: 0.767, Time: 1.1s, Iters: 39
# - Ratio: 0.607, Time: 0.9s, Iters: 30
# - Ratio: 0.607, Time: 0.7s, Iters: 24
#
# ======================================================================
# Graph: 10 nodes | Depth: p=2
# ======================================================================
#
#   Strategy: Random
# - Ratio: 0.610, Time: 3.6s, Iters: 80
# - Ratio: 0.616, Time: 6.2s, Iters: 145
# - Ratio: 0.610, Time: 2.8s, Iters: 65
# - Ratio: 0.768, Time: 5.5s, Iters: 125
# - Ratio: 0.616, Time: 4.3s, Iters: 95
# - Ratio: 0.771, Time: 5.0s, Iters: 115
# - Ratio: 0.853, Time: 6.8s, Iters: 155
# - Ratio: 0.853, Time: 4.0s, Iters: 95
# - Ratio: 0.767, Time: 5.1s, Iters: 115
# - Ratio: 0.853, Time: 4.9s, Iters: 110
#
#   Strategy: Fixed
#     Ratio: 0.8525, Time: 3.53s, Iterations: 80
#
#   Strategy: TQA
#     Ratio: 0.8225, Time: 3.88s, Iterations: 85
#
#   Strategy: Warm-Start
# - Ratio: 0.853, Time: 2.8s, Iters: 65
# - Ratio: 0.853, Time: 2.7s, Iters: 60
# - Ratio: 0.853, Time: 2.5s, Iters: 55
# - Ratio: 0.853, Time: 2.6s, Iters: 55
# - Ratio: 0.853, Time: 2.2s, Iters: 50
# - Ratio: 0.853, Time: 2.4s, Iters: 55
# - Ratio: 0.853, Time: 2.6s, Iters: 55
# - Ratio: 0.853, Time: 2.9s, Iters: 65
# - Ratio: 0.853, Time: 2.0s, Iters: 45
# - Ratio: 0.853, Time: 2.4s, Iters: 50
#
# ======================================================================
# Graph: 12 nodes | Depth: p=1
# ======================================================================
#
#   Strategy: Random
# - Ratio: 0.617, Time: 0.9s, Iters: 21
# - Ratio: 0.719, Time: 1.6s, Iters: 36
# - Ratio: 0.617, Time: 1.0s, Iters: 24
# - Ratio: 0.617, Time: 1.5s, Iters: 36
# - Ratio: 0.617, Time: 0.7s, Iters: 18
# - Ratio: 0.617, Time: 1.7s, Iters: 39
# - Ratio: 0.719, Time: 1.7s, Iters: 42
# - Ratio: 0.719, Time: 1.0s, Iters: 24
# - Ratio: 0.617, Time: 1.0s, Iters: 24
# - Ratio: 0.719, Time: 1.4s, Iters: 33
#
#   Strategy: Fixed
#     Ratio: 0.7194, Time: 1.39s, Iterations: 33
#
#   Strategy: TQA
#     Ratio: 0.7194, Time: 1.55s, Iterations: 33
#
#   Strategy: Warm-Start
# - Ratio: 0.719, Time: 1.5s, Iters: 36
# - Ratio: 0.549, Time: 1.3s, Iters: 30
# - Ratio: 0.549, Time: 1.7s, Iters: 39
# - Ratio: 0.549, Time: 2.4s, Iters: 57
# - Ratio: 0.617, Time: 0.9s, Iters: 21
# - Ratio: 0.617, Time: 1.3s, Iters: 30
# - Ratio: 0.617, Time: 1.4s, Iters: 33
# - Ratio: 0.719, Time: 1.8s, Iters: 42
# - Ratio: 0.617, Time: 2.3s, Iters: 54
# - Ratio: 0.617, Time: 1.5s, Iters: 33
#
# ======================================================================
# Graph: 12 nodes | Depth: p=2
# ======================================================================
#
#   Strategy: Random
# - Ratio: 0.740, Time: 14.9s, Iters: 230
# - Ratio: 0.791, Time: 15.9s, Iters: 245
# - Ratio: 0.631, Time: 9.8s, Iters: 145
# - Ratio: 0.725, Time: 7.0s, Iters: 105
# - Ratio: 0.629, Time: 7.8s, Iters: 115
# - Ratio: 0.740, Time: 10.6s, Iters: 160
# - Ratio: 0.631, Time: 12.1s, Iters: 180
# - Ratio: 0.801, Time: 8.0s, Iters: 115
# - Ratio: 0.740, Time: 6.1s, Iters: 85
# - Ratio: 0.801, Time: 4.4s, Iters: 65
#
#   Strategy: Fixed
#     Ratio: 0.8014, Time: 6.17s, Iterations: 90
#
#   Strategy: TQA
#     Ratio: 0.7716, Time: 4.61s, Iterations: 65
#
#   Strategy: Warm-Start
# - Ratio: 0.801, Time: 4.2s, Iters: 60
# - Ratio: 0.801, Time: 4.4s, Iters: 65
# - Ratio: 0.801, Time: 3.8s, Iters: 55
# - Ratio: 0.801, Time: 3.4s, Iters: 50
# - Ratio: 0.801, Time: 3.2s, Iters: 45
# - Ratio: 0.801, Time: 3.8s, Iters: 55
# - Ratio: 0.801, Time: 3.4s, Iters: 50
# - Ratio: 0.801, Time: 4.0s, Iters: 60
# - Ratio: 0.801, Time: 3.2s, Iters: 45
# - Ratio: 0.801, Time: 3.5s, Iters: 50

# %%
stats = {}

for n_wires in [8, 10, 12]:
    stats[n_wires] = {}
    
    for p in [1, 2]:
        stats[n_wires][p] = {}
        
        for strategy_name in strategies.keys():
            trials = results[n_wires][p][strategy_name]
            
            stats[n_wires][p][strategy_name] = {
                'mean_ratio': np.mean([t['approx_ratio'] for t in trials]),
                'std_ratio': np.std([t['approx_ratio'] for t in trials]),
                'mean_time': np.mean([t['time'] for t in trials]),
                'std_time': np.std([t['time'] for t in trials]),
                'mean_iters': np.mean([t['iterations'] for t in trials]),
                'std_iters': np.std([t['iterations'] for t in trials]),
                'mean_conv_iter': np.mean([t['convergence_iter'] for t in trials]),
                'mean_time_to_95': np.mean([t['time_to_95'] for t in trials]),
                'success_rate': sum([t['success'] for t in trials]) / len(trials) * 100
            }

# %%
for n_wires in [8, 10, 12]:
    for p in [1, 2]:
        print(f"\n{n_wires}-node graph, p={p} (Optimal cut = {optimal_cuts[n_wires]}):")
        print("-"*110)
        print(f"{'Strategy':<15} {'Avg Ratio':<15} {'Time (s)':<12} "
              f"{'Iters':<10} {'Conv Iter':<12} {'Time to 95%':<12} {'Success %':<10}")
        print("-"*110)
        
        for strategy_name in strategies.keys():
            s = stats[n_wires][p][strategy_name]
            print(f"{strategy_name:<15} "
                  f"{s['mean_ratio']:.4f}±{s['std_ratio']:.4f}   "
                  f"{s['mean_time']:.2f}±{s['std_time']:.2f}   "
                  f"{s['mean_iters']:.0f}±{s['std_iters']:.0f}   "
                  f"{s['mean_conv_iter']:.0f}           "
                  f"{s['mean_time_to_95']:.2f}s         "
                  f"{s['success_rate']:.0f}%")
        print("-"*110)
# Out:
# 8-node graph, p=1 (Optimal cut = 13):
# --------------------------------------------------------------------------------------------------------------
# Strategy        Avg Ratio       Time (s)     Iters      Conv Iter    Time to 95%  Success %
# --------------------------------------------------------------------------------------------------------------
# Random          0.6149±0.0440   0.66±0.15   32±7   1           0.25s         0%
# Fixed           0.6821±0.0000   0.62±0.00   30±0   1           0.28s         0%
# TQA             0.6821±0.0000   0.63±0.00   30±0   2           0.23s         0%
# Warm-Start      0.6053±0.0384   1.89±0.49   35±10   1           0.86s         0%
# --------------------------------------------------------------------------------------------------------------
#
# 8-node graph, p=2 (Optimal cut = 13):
# --------------------------------------------------------------------------------------------------------------
# Strategy        Avg Ratio       Time (s)     Iters      Conv Iter    Time to 95%  Success %
# --------------------------------------------------------------------------------------------------------------
# Random          0.6632±0.0699   4.01±1.49   126±47   3           1.10s         0%
# Fixed           0.8228±0.0000   2.35±0.00   75±0   2           0.87s         0%
# TQA             0.7605±0.0000   3.01±0.00   95±0   3           1.31s         0%
# Warm-Start      0.8228±0.0000   1.65±0.11   52±3   0           0.48s         0%
# --------------------------------------------------------------------------------------------------------------
#
# 10-node graph, p=1 (Optimal cut = 15):
# --------------------------------------------------------------------------------------------------------------
# Strategy        Avg Ratio       Time (s)     Iters      Conv Iter    Time to 95%  Success %
# --------------------------------------------------------------------------------------------------------------
# Random          0.6713±0.0783   0.97±0.41   35±15   1           0.40s         0%
# Fixed           0.7673±0.0000   0.83±0.00   30±0   1           0.36s         0%
# TQA             0.7673±0.0000   0.90±0.00   30±0   2           0.33s         0%
# Warm-Start      0.6553±0.0733   1.03±0.34   36±14   1           0.43s         0%
# --------------------------------------------------------------------------------------------------------------
#
# 10-node graph, p=2 (Optimal cut = 15):
# --------------------------------------------------------------------------------------------------------------
# Strategy        Avg Ratio       Time (s)     Iters      Conv Iter    Time to 95%  Success %
# --------------------------------------------------------------------------------------------------------------
# Random          0.7317±0.1021   4.82±1.15   110±26   3           1.69s         0%
# Fixed           0.8525±0.0000   3.53±0.00   80±0   3           1.95s         0%
# TQA             0.8225±0.0000   3.88±0.00   85±0   2           1.43s         0%
# Warm-Start      0.8525±0.0000   2.52±0.25   56±6   0           0.58s         0%
# --------------------------------------------------------------------------------------------------------------
#
# 12-node graph, p=1 (Optimal cut = 21):
# --------------------------------------------------------------------------------------------------------------
# Strategy        Avg Ratio       Time (s)     Iters      Conv Iter    Time to 95%  Success %
# --------------------------------------------------------------------------------------------------------------
# Random          0.6580±0.0501   1.26±0.33   30±8   0           0.39s         0%
# Fixed           0.7194±0.0000   1.39±0.00   33±0   2           0.70s         0%
# TQA             0.7194±0.0000   1.55±0.00   33±0   2           0.52s         0%
# Warm-Start      0.6171±0.0590   1.59±0.45   38±10   1           0.57s         0%
# --------------------------------------------------------------------------------------------------------------
#
# 12-node graph, p=2 (Optimal cut = 21):
# --------------------------------------------------------------------------------------------------------------
# Strategy        Avg Ratio       Time (s)     Iters      Conv Iter    Time to 95%  Success %
# --------------------------------------------------------------------------------------------------------------
# Random          0.7229±0.0661   9.65±3.56   144±57   4           4.26s         0%
# Fixed           0.8014±0.0000   6.17±0.00   90±0   3           2.87s         0%
# TQA             0.7716±0.0000   4.61±0.00   65±0   2           1.71s         0%
# Warm-Start      0.8014±0.0000   3.70±0.40   54±6   0           0.90s         0%
# --------------------------------------------------------------------------------------------------------------

# %%
fig, axes = plt.subplots(3,2 , figsize=(16, 10))

colors = {'Random': 'blue', 'Fixed': 'green', 'TQA': 'red', 
          'Warm-Start': 'purple', 'Near-Optimal': 'orange'}

for row, n_wires in enumerate([8, 10, 12]):
    for col, p in enumerate([1, 2]):
        ax = axes[row, col]
        
        for strategy_name in strategies.keys():
            trials = results[n_wires][p][strategy_name]
            all_histories = [t['convergence_history'] for t in trials]
            
            # Find max iterations
            max_iters = max(len(h['cost']) for h in all_histories)
            
            # Pad histories
            padded_costs = []
            for h in all_histories:
                padded = list(h['cost'])
                if len(padded) < max_iters:
                    padded.extend([padded[-1]] * (max_iters - len(padded)))
                padded_costs.append(padded)
            
            # Mean and std
            mean_cost = np.mean(padded_costs, axis=0)
            std_cost = np.std(padded_costs, axis=0)
            iterations = range(1, len(mean_cost) + 1)
            
            # Plot
            ax.plot(iterations, mean_cost, label=strategy_name,
                   color=colors[strategy_name], linewidth=2)
            ax.fill_between(iterations,
                           mean_cost - std_cost,
                           mean_cost + std_cost,
                           color=colors[strategy_name], alpha=0.2)
        
        ax.set_xlabel('Iteration', fontsize=11)
        ax.set_ylabel('Objective Value', fontsize=11)
        ax.set_title(f'{n_wires} nodes, p={p}', fontsize=12, fontweight='bold')
        ax.legend(fontsize=9, loc='best')
        ax.grid(True, alpha=0.3)

plt.suptitle('Convergence Comparison: Initialization Strategies', 
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
import numpy as np

# Create comparison table
comparison_data = []

for p in [1, 2]:
    # Added 12 to include all three graph sizes
    for strategy_name in strategies.keys():
        avg_ratio = np.mean([stats[n_wires][p][strategy_name]['mean_ratio'] 
                            for n_wires in [8, 10, 12]])
        avg_time = np.mean([stats[n_wires][p][strategy_name]['mean_time'] 
                           for n_wires in [8, 10, 12]])
        avg_conv = np.mean([stats[n_wires][p][strategy_name]['mean_conv_iter'] 
                           for n_wires in [8, 10, 12]])
        avg_success = np.mean([stats[n_wires][p][strategy_name]['success_rate'] 
                              for n_wires in [8, 10, 12]])
        
        comparison_data.append({
            'p': p,
            'Strategy': strategy_name,
            'Avg Ratio': avg_ratio,
            'Avg Time (s)': avg_time,
            'Avg Conv Iter': avg_conv,
            'Success Rate (%)': avg_success
        })
    
    # Updated the lambda search functions to average across 8, 10, and 12
    best_quality = max(strategies.keys(), 
                      key=lambda s: np.mean([stats[n][p][s]['mean_ratio'] for n in [8, 10, 12]]))
    fastest = min(strategies.keys(),
                 key=lambda s: np.mean([stats[n][p][s]['mean_time'] for n in [8, 10, 12]]))
    best_conv = min(strategies.keys(),
                   key=lambda s: np.mean([stats[n][p][s]['mean_conv_iter'] for n in [8, 10, 12]]))
    most_robust = max(strategies.keys(),
                     key=lambda s: np.mean([stats[n][p][s]['success_rate'] for n in [8, 10, 12]]))
    
    print(f"\n--- Summary for p={p} (Averaged over 8, 10, 12 nodes) ---")
    print(f"  Best Quality:      {best_quality}")
    print(f"  Fastest:           {fastest}")
    print(f"  Best Convergence: {best_conv}")
    print(f"  Most Robust:       {most_robust}")
# Out:
# --- Summary for p=1 (Averaged over 8, 10, 12 nodes) ---
#   Best Quality:      Fixed
#   Fastest:           Fixed
#   Best Convergence: Random
#   Most Robust:       Random
#
# --- Summary for p=2 (Averaged over 8, 10, 12 nodes) ---
#   Best Quality:      Fixed
#   Fastest:           Warm-Start
#   Best Convergence: Warm-Start
#   Most Robust:       Random
